# %%
print('Hello')
# Out:
# Hello

# %% [markdown]
# pandas

# %%
import pandas as pd
S={"Name" : ["Chittu","Sittu","Kittu","Minnu","Chinnu","Munnu","Kichu","Appu","Kuttan"],"Age": ["30","18","17","17","35","30","30","18","18"],"Number of letters in name": ["6","11","12","6","7","5","4","3","2"]}
S=pd.DataFrame(S)
S
# Out:
#      Name Age Number of letters in name
# 0  Chittu  30                         6
# 1   Sittu  18                        11
# 2   Kittu  17                        12
# 3   Minnu  17                         6
# 4  Chinnu  35                         7
# 5   Munnu  30                         5
# 6   Kichu  30                         4
# 7    Appu  18                         3
# 8  Kuttan  18                         2

# %%
#to_excel()
S.to_excel('Fam.xlsx')

# %%
S=pd.read_excel('Fam.xlsx',index_col='Unnamed: 0')
S
# Out:
#      Name  Age  Number of letters in name
# 0  Chittu   30                          6
# 1   Sittu   18                         11
# 2   Kittu   17                         12
# 3   Minnu   17                          6
# 4  Chinnu   35                          7
# 5   Munnu   30                          5
# 6   Kichu   30                          4
# 7    Appu   18                          3
# 8  Kuttan   18                          2

# %%
#csv
S.to_csv('Fam.csv')
S=pd.read_excel('Fam.xlsx',index_col='Unnamed: 0')
S
# Out:
#      Name  Age  Number of letters in name
# 0  Chittu   30                          6
# 1   Sittu   18                         11
# 2   Kittu   17                         12
# 3   Minnu   17                          6
# 4  Chinnu   35                          7
# 5   Munnu   30                          5
# 6   Kichu   30                          4
# 7    Appu   18                          3
# 8  Kuttan   18                          2

# %%
S.shape
# Out:
# (9, 3)

# %%
S.head(3)
# Out:
#      Name  Age  Number of letters in name
# 0  Chittu   30                          6
# 1   Sittu   18                         11
# 2   Kittu   17                         12

# %%
S.tail()
# Out:
#      Name  Age  Number of letters in name
# 4  Chinnu   35                          7
# 5   Munnu   30                          5
# 6   Kichu   30                          4
# 7    Appu   18                          3
# 8  Kuttan   18                          2

# %%
S.columns
# Out:
# Index(['Name', 'Age', 'Number of letters in name'], dtype='object')

# %%
S.Name
# Out:
# 0    Chittu
# 1     Sittu
# 2     Kittu
# 3     Minnu
# 4    Chinnu
# 5     Munnu
# 6     Kichu
# 7      Appu
# 8    Kuttan
# Name: Name, dtype: object

# %%
S[['Name','Age']]
# Out:
#      Name  Age
# 0  Chittu   30
# 1   Sittu   18
# 2   Kittu   17
# 3   Minnu   17
# 4  Chinnu   35
# 5   Munnu   30
# 6   Kichu   30
# 7    Appu   18
# 8  Kuttan   18

# %%
S[1:5]
# Out:
#      Name  Age  Number of letters in name
# 1   Sittu   18                         11
# 2   Kittu   17                         12
# 3   Minnu   17                          6
# 4  Chinnu   35                          7

# %%
S[1:]
# Out:
#      Name  Age  Number of letters in name
# 1   Sittu   18                         11
# 2   Kittu   17                         12
# 3   Minnu   17                          6
# 4  Chinnu   35                          7
# 5   Munnu   30                          5
# 6   Kichu   30                          4
# 7    Appu   18                          3
# 8  Kuttan   18                          2

# %%
S[:5]
# Out:
#      Name  Age  Number of letters in name
# 0  Chittu   30                          6
# 1   Sittu   18                         11
# 2   Kittu   17                         12
# 3   Minnu   17                          6
# 4  Chinnu   35                          7

# %%
S.sort_values('Age',ascending=False)
# Out:
#      Name  Age  Number of letters in name
# 4  Chinnu   35                          7
# 0  Chittu   30                          6
# 5   Munnu   30                          5
# 6   Kichu   30                          4
# 1   Sittu   18                         11
# 7    Appu   18                          3
# 8  Kuttan   18                          2
# 2   Kittu   17                         12
# 3   Minnu   17                          6

# %%
S.index
# Out:
# Int64Index([0, 1, 2, 3, 4, 5, 6, 7, 8], dtype='int64')

# %%
S.set_index('Name')
# Out:
#         Age  Number of letters in name
# Name
# Chittu   30                          6
# Sittu    18                         11
# Kittu    17                         12
# Minnu    17                          6
# Chinnu   35                          7
# Munnu    30                          5
# Kichu    30                          4
# Appu     18                          3
# Kuttan   18                          2

# %%
S.Age.max()
# Out:
# 35

# %%
S.Age.min()
# Out:
# 17

# %%
S.Age.mean()
# Out:
# 23.666666666666668

# %%
S.Age.std()
# Out:
# 7.365459931328117

# %%
S={"Name" : ["Chittu",None,"Kittu","Minnu","Chinnu","Munnu","Kichu","Appu","Kuttan"],"Age": ["30",None,"17","17","35","30","30","18","18"],"Number of letters in name": ["6",None,"12","6","7","5","4","3","2"]}
S=pd.DataFrame(S)
S
# Out:
#      Name   Age Number of letters in name
# 0  Chittu    30                         6
# 1    None  None                      None
# 2   Kittu    17                        12
# 3   Minnu    17                         6
# 4  Chinnu    35                         7
# 5   Munnu    30                         5
# 6   Kichu    30                         4
# 7    Appu    18                         3
# 8  Kuttan    18                         2

# %%
#to_excel()
S.to_excel('Fam.xlsx')

# %%
#to_csv()
S.to_csv('Fam.csv')

# %%
#fillna
#interpolate
#replace
newdf=S.fillna({'Name':'Sittu','Age':'18','Numbers of letter in name':'11'})
newdf
# Out:
#      Name Age Number of letters in name
# 0  Chittu  30                         6
# 1   Sittu  18                      None
# 2   Kittu  17                        12
# 3   Minnu  17                         6
# 4  Chinnu  35                         7
# 5   Munnu  30                         5
# 6   Kichu  30                         4
# 7    Appu  18                         3
# 8  Kuttan  18                         2
